# %%
'''
what is PyPi?
    - The Python Package Index (PyPI) is a repository of software for the Python programming language.
    
Required files PyPi needs?
    - setup.py
    - setup.cfg
    - LICENSE.txt
    - README.md (optinal but highly recommended)
    
setup.py
  - The setup.py file contains information about your package that PyPi needs
    - Name
    - Description
    - Current Version
    
Create a source distribution with the following command
    - python setup.py sdist
    
Use twine for the upload process
    - pip install twine

# %%
'''
Below the code you can download from the github link

https://github.com/SanthoshNKumar/Python/blob/master/Create%20PYPI%20Package/PyMyCustomCalc.7z

# %%
'''
Steps 

Step 1. Create a Directory or Main Project Folder

# %% [markdown]
# ![1.png](attachment:1.png)

# %%
'''
Step 2. Write your python module and save it under a directory

# %% [markdown]
# ![2.png](attachment:2.png)

# %%
'''
Step 3. Create Below the files
    - setup.py
    - setup.cfg
    - LICENSE.txt
    - MANIFEST.in
    - README.md

# %% [markdown]
# ![3.png](attachment:3.png)

# %%
'''
Step 4. Create 'dist' folder inside Package

# %% [markdown]
# ![4.png](attachment:4.png)

# %%
'''
Step 5.. Generate the distribution archives on local machine (tar file) using below the command
    - C:\Users\bmi_cims\PyMyCustomCalc>python setup.py sdist

# %% [markdown]
# ![5.png](attachment:5.png)

# %%
'''
Step 6. Try installing the package on your local machine using below the command
    - C:\Users\bmi_cims\PyMyCustomCalc\dist>pip install pycustomcalc-0.1.tar.gz

# %% [markdown]
# ![6.png](attachment:6.png)

# %%
'''
Step 7. Upload the package into Pypi
        - Install package twine
            pip install twine
        - Twine will help us to upload tar file into pypi
        - Upload tar file using below the command
            C:\Users\bmi_cims\PyMyCustomCalc>twine upload dist/*

# %% [markdown]
# ![7.png](attachment:7.png)

# %%
'''

Step 8. Finally, publish the package to the PyPi repository using below the command
    - C:\Users\bmi_cims\PyMyCustomCalc>twine upload dist/*
    - Enter Username and Password

# %% [markdown]
# ![8.png](attachment:8.png)

# %%
'''
You can find the patch on pypi org

# %% [markdown]
# ![9.png](attachment:9.png)
